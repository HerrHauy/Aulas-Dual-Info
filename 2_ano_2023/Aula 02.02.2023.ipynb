# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Resolvendo o exercício da última aula

# %% [markdown]
# Solução do sr. Lan

# %%
def plota_sen_lan(x0,xf,n):
    
    xpoints = np.linspace(x0,xf,n)
    ypoints = []
    
    for i in xpoints:
        ypoints.append(np.sin(i))
        
    plt.plot(xpoints,ypoints)
    plt.show()

# %% [markdown]
# Entendendo o linspace

# %%
np.linspace(10,25,15)
# Out:
# array([10.        , 11.07142857, 12.14285714, 13.21428571, 14.28571429,
#        15.35714286, 16.42857143, 17.5       , 18.57142857, 19.64285714,
#        20.71428571, 21.78571429, 22.85714286, 23.92857143, 25.        ])

# %% [markdown]
# Testando o plot

# %%
plota_sen_lan(-np.pi,np.pi,20)

# %% [markdown]
# Solução sem linspace

# %%
def plota_sen(x0,xf,n):
    
    xpoints = []
    ypoints = []
    
    for i in range(0,n):
        xpoints.append((xf-x0)*i/(n-1)+x0)
        ypoints.append(np.sin((xf-x0)*i/(n-1)+x0))
        
    plt.plot(xpoints,ypoints)
    plt.show()

# %%
plota_sen(-np.pi,np.pi,20)

# %% [markdown]
# Criar códigos que executam as seguintes funções, recebendo inputs externos (input()):
#
# - Função que encontra o maior número entre 3 dados pelo usuário.
# - Função que inverte uma string dada pelo usuário ('abc123' vira '321cba').
# - Função que calcula o fatorial de um número dado pelo usuário.
# - Função que printa as n primeiras fileiras do triângulo de pascal, onde n é dado pelo usuário.

# %% [markdown]
# Condensando tudo em um formato executável:

# %%
import numpy as np
import matplotlib.pyplot as plt

def plota_sen_lan(x0,xf,n):
    
    xpoints = np.linspace(x0,xf,n)
    ypoints = []
    
    for i in xpoints:
        ypoints.append(np.sin(i))
        
    plt.plot(xpoints,ypoints)
    plt.show()
    
    
x0 = float(input('Valor inicial do plot:'))
xf = float(input('Valor final do plot:'))
n = int(input('Número de pontos do plot:'))
plota_sen_lan(x0,xf,n)
# Out:
# Valor inicial do plot:3
# Valor final do plot:7
# Número de pontos do plot:9

# %% [markdown]
# Transformando em um executável:
#
# - salvar como .py
# - No kernel do anaconda
# pip install auto-py-to-exe
# - run
# auto-py-to-exe
#
# No Linux simplesmente
#
# python nome.py
#
# para executar.

# %%
i=1
while i>0:
    x = input('Diga um número')
    if x=='quit':
        break
    else:
        print(x)
# Out:
# Diga um número4
# 4
# Diga um número5
# 5
# Diga um número6
# 6
# Diga um número3
# 3
# Diga um número5
# 5
# Diga um númeroquit
